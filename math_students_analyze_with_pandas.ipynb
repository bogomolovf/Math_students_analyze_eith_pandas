# %%
import pandas as pd

# %%
file = pd.read_csv("math_students.csv")

# %%
file.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
file.iloc[::2]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Выводим только учеников с чётным количество пропусков

# %%
file[(file['absences'] % 2 == 0)]
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
biggerthanten = file[(file['absences'] > 10)]

# %% [markdown]
# Выводим учеников с количеством пропусков больше 10

# %%
biggerthanten[['G3']].mean(axis=1)
# Out:
# 18      5.0
# 25      8.0
# 29     11.0
# 40     11.0
# 44      9.0
#        ...
# 342    15.0
# 373     5.0
# 379    10.0
# 384     5.0
# 390     9.0
# Length: 66, dtype: float64

# %%
biggerthanten
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 18      GP   M   17       U     GT3       T     3     2  services  services
# 25      GP   F   16       U     GT3       T     2     2  services  services
# 29      GP   M   16       U     GT3       T     4     4   teacher   teacher
# 40      GP   F   16       U     LE3       T     2     2     other     other
# 44      GP   F   16       U     LE3       T     2     2     other   at_home
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 342     GP   M   18       U     LE3       T     3     4  services     other
# 373     MS   F   17       R     GT3       T     1     2     other     other
# 379     MS   F   17       R     GT3       T     3     1   at_home     other
# 384     MS   M   18       R     GT3       T     4     2     other     other
# 390     MS   M   20       U     LE3       A     2     2  services  services
#
# ...

# %% [markdown]
# Теперь сравним среднюю итоговую оценку по ученикам с большим числом пропусков со средней оценкой по всем ученикам

# %%
biggerthanten[['G3']].mean(axis=1).mean()
# Out:
# 10.151515151515152

# %%
file[['G3']].mean(axis=1).mean()
# Out:
# 10.415189873417722

# %% [markdown]
# 10.151515151515152 < 10.415189873417722 т.е. те кто много пропускал учатся хуже

# %%
file
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
female = file[(file['sex'] == 'F')]

# %%
female
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 389     MS   F   18       U     GT3       T     1     1     other     other
#
# ...

# %%
male = file[(file['sex'] == 'M')]

# %%
male
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# 9       GP   M   15       U     GT3       T     3     4     other     other
# 12      GP   M   15       U     LE3       T     4     4    health  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
female[['G3']].mean(axis=1).mean()
# Out:
# 9.966346153846153

# %%
male[['G3']].mean(axis=1).mean()
# Out:
# 10.914438502673796

# %% [markdown]
# В результате сравнения средних оценок по полу оказалось, что юноши из этих двух математических школ в среднем учатся лучше девушек

# %%
file
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
extralessons = file[(file['paid'] == 'yes')]

# %%
extralessons
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# 8       GP   M   15       U     LE3       A     3     2  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 384     MS   M   18       R     GT3       T     4     2     other     other
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 386     MS   F   18       R     GT3       T     4     4   teacher   at_home
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 390     MS   M   20       U     LE3       A     2     2  services  services
#
# ...

# %%
noextralessons = file[(file['paid'] == 'no')]

# %%
extralessons[['G3']].mean(axis=1).mean()
# Out:
# 10.922651933701658

# %%
noextralessons[['G3']].mean(axis=1).mean()
# Out:
# 9.985981308411215

# %% [markdown]
# 10.922651933701658 > 9.985981308411215, средняя оценка тех кто занимаются дополнительно почти на балл выше тех кто занимается сам

# %%
closetohome = file[(file['reason'] == 'home')]

# %%
closetohome
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 6       GP   M   16       U     LE3       T     2     2     other     other
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 8       GP   M   15       U     LE3       A     3     2  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 375     MS   F   18       R     GT3       T     1     1     other     other
# 378     MS   F   18       U     GT3       T     3     3     other     other
# 380     MS   M   18       U     GT3       T     4     4   teacher   teacher
# 382     MS   M   17       U     GT3       T     2     3     other  services
# 384     MS   M   18       R     GT3       T     4     2     other     other
#
# ...

# %%
first = file[(file['traveltime'] == 1)]
second = file[(file['traveltime'] == 2)]
third = file[(file['traveltime'] == 3)]
fourth = file[(file['traveltime'] == 4)]

# %%
first
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# 5       GP   M   16       U     LE3       T     4     3  services     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 387     MS   F   19       R     GT3       T     2     3  services     other
# 388     MS   F   18       U     LE3       T     3     1   teacher  services
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
second
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 7       GP   F   17       U     GT3       A     4     4     other   teacher
# 13      GP   M   15       U     GT3       T     4     3   teacher     other
# 23      GP   M   16       U     LE3       T     2     2     other     other
# 31      GP   M   15       U     GT3       T     4     4  services  services
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 383     MS   M   19       R     GT3       T     1     1     other  services
# 384     MS   M   18       R     GT3       T     4     2     other     other
# 385     MS   F   18       R     GT3       T     2     2   at_home     other
# 389     MS   F   18       U     GT3       T     1     1     other     other
# 391     MS   M   17       U     LE3       T     3     1  services  services
#
# ...

# %%
third
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 11      GP   F   15       U     GT3       T     2     1  services     other
# 17      GP   F   16       U     GT3       T     3     3     other     other
# 50      GP   F   16       U     LE3       T     2     2  services  services
# 65      GP   F   16       U     LE3       T     4     3   teacher  services
# 118     GP   M   17       R     GT3       T     1     3     other     other
# 131     GP   F   15       U     GT3       T     1     1   at_home     other
# 136     GP   M   17       R     GT3       T     3     4   at_home     other
# 157     GP   F   18       R     GT3       T     1     1   at_home     other
# 158     GP   M   16       R     GT3       T     2     2   at_home     other
# 170     GP   M   16       U     GT3       T     3     4     other     other
# 197     GP   M   16       R     LE3       T     3     3   teacher     other
# ...

# %%
fourth
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 61      GP   F   16       U     GT3       T     1     1  services  services
# 108     GP   M   15       R     GT3       T     4     4     other     other
# 134     GP   M   15       R     GT3       T     3     4   at_home   teacher
# 149     GP   M   15       U     LE3       A     2     1  services     other
# 164     GP   M   17       R     LE3       T     1     1     other  services
# 228     GP   M   18       U     LE3       T     2     1   at_home     other
# 327     GP   M   17       R     GT3       T     2     2  services     other
# 375     MS   F   18       R     GT3       T     1     1     other     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 61   ...      5        5      5     5     5      5        6  10   8  11
# 108  ...      1        3      5     3     5      1        6  10  13  13
# ...

# %%
file
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# 364 человека из 395(first и second) живут в получасовой доступности от школы, это свидетельствует о том что открытие общежития около школы будет неактуально

# %%
female[['G3']].mean(axis=1).mean()
male[['G3']].mean(axis=1).mean()

# %%
grouped = file.groupby('sex')['absences'].mean()

# %%
grouped
# Out:
# sex
# F    6.216346
# M    5.144385
# Name: absences, dtype: float64

# %% [markdown]
# Получилось, что в средем девушки пропускают занятия чаще юношей

# %%
measure = file.pivot_table(values=['Dalc', 'Walc'], index='school', aggfunc='mean', fill_value=0)

# %%
measure
# Out:
#             Dalc      Walc
# school
# GP      1.444126  2.260745
# MS      1.760870  2.521739

# %% [markdown]
# Алкоголь чаще употребяют в школе MS(Dals - будни, Walc - выходные)

# %%
FvsM = file.pivot_table(values=['Medu', 'Fedu'], index='school', aggfunc='mean', fill_value=0)

# %%
FvsM
# Out:
#             Fedu      Medu
# school
# GP      2.553009  2.802292
# MS      2.282609  2.347826

# %% [markdown]
# Medu - образование матери (0 - никакого, 1 - начальное образование (4 класса), 2 – от 5 до 9 классов, 3 – среднеспециальное или 4 – высшее)
#
# Fedu - образование отца (0 - никакого, 1 - начальное образование (4 класса), 2 – от 5 до 9 классов, 3 – среднеспециальное или 4 – высшее)

# %% [markdown]
# Получилось что в среднем родители учеников из школы GP - более обрахованные люди

# %% [markdown]
# Вывод: школа GP благополученее школы MS
